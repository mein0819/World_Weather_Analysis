# %%
# Import the dependencies.
import pandas as pd
import time
import numpy as np
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid="+ weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | port hardy
# Processing Record 3 of Set 1 | coquimbo
# Processing Record 4 of Set 1 | riyadh
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | hailar
# Processing Record 7 of Set 1 | aitape
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | saint-philippe
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | port elizabeth
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | autazes
# Processing Record 15 of Set 1 | pevek
# Processing Record 16 of Set 1 | ribeira grande
# Processing Record 17 of Set 1 | provideniya
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | esperance
# Processing Record 21 of Set 1 | nicolas de pierola
# Processing Record 22 of Set 1 | bilibino
# Processing Record 23 of Set 1 | crab hill
# City not found. Skipping...
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | kavieng
# Processing Record 26 of Set 1 | rio gallegos
# Processing Record 27 of Set 1 | tuktoyaktuk
# Processing Record 28 of Set 1 | saskylakh
# Processing Record 29 of Set 1 | omsukchan
# Processing Record 30 of Set 1 | tazovskiy
# Processing Record 31 of Set 1 | lata
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | guangzhou
# Processing Record 34 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | tiksi
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | westport
# Processing Record 40 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 1 | kamenka
# Processing Record 42 of Set 1 | avarua
# Processing Record 43 of Set 1 | saravan
# Processing Record 44 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | victoria
# Processing Record 48 of Set 1 | marsa matruh
# Processing Record 49 of Set 1 | kahului
# Processing Record 50 of Set 1 | shillong
# Processing Record 1 of Set 2 | flinders
# Processing Record 2 of Set 2 | cap malheureux
# Processing Record 3 of Set 2 | baker city
# Processing Record 4 of Set 2 | whitecourt
# Processing Record 5 of Set 2 | ca mau
# Processing Record 6 of Set 2 | san quintin
# Processing Record 7 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 2 | halifax
# Processing Record 10 of Set 2 | cidreira
# Processing Record 11 of Set 2 | abu jubayhah
# City not found. Skipping...
# Processing Record 12 of Set 2 | tomatlan
# Processing Record 13 of Set 2 | mar del plata
# Processing Record 14 of Set 2 | manado
# Processing Record 15 of Set 2 | lebu
# Processing Record 16 of Set 2 | makakilo city
# Processing Record 17 of Set 2 | tekeli
# Processing Record 18 of Set 2 | georgetown
# Processing Record 19 of Set 2 | talnakh
# Processing Record 20 of Set 2 | torbay
# Processing Record 21 of Set 2 | medyn
# Processing Record 22 of Set 2 | bengkulu
# Processing Record 23 of Set 2 | usinsk
# Processing Record 24 of Set 2 | moerai
# Processing Record 25 of Set 2 | upernavik
# Processing Record 26 of Set 2 | jinchang
# Processing Record 27 of Set 2 | cabedelo
# Processing Record 28 of Set 2 | isangel
# Processing Record 29 of Set 2 | clyde river
# Processing Record 30 of Set 2 | nagato
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | east london
# Processing Record 33 of Set 2 | barrow
# Processing Record 34 of Set 2 | saravena
# Processing Record 35 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 2 | cherskiy
# Processing Record 37 of Set 2 | gorele
# Processing Record 38 of Set 2 | yellowknife
# Processing Record 39 of Set 2 | castro
# Processing Record 40 of Set 2 | narsaq
# Processing Record 41 of Set 2 | ilulissat
# Processing Record 42 of Set 2 | kawana waters
# City not found. Skipping...
# Processing Record 43 of Set 2 | carballo
# Processing Record 44 of Set 2 | kendari
# Processing Record 45 of Set 2 | gat
# Processing Record 46 of Set 2 | eureka
# Processing Record 47 of Set 2 | butaritari
# Processing Record 48 of Set 2 | kaitangata
# Processing Record 49 of Set 2 | kifri
# Processing Record 50 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 3 | mahebourg
# Processing Record 2 of Set 3 | carnarvon
# Processing Record 3 of Set 3 | luderitz
# Processing Record 4 of Set 3 | tuatapere
# Processing Record 5 of Set 3 | qaanaaq
# Processing Record 6 of Set 3 | cayenne
# Processing Record 7 of Set 3 | ahuimanu
# Processing Record 8 of Set 3 | bani
# Processing Record 9 of Set 3 | san jose
# Processing Record 10 of Set 3 | bang lamung
# Processing Record 11 of Set 3 | erenhot
# Processing Record 12 of Set 3 | nanortalik
# Processing Record 13 of Set 3 | airai
# Processing Record 14 of Set 3 | atuona
# Processing Record 15 of Set 3 | miramar
# Processing Record 16 of Set 3 | tasiilaq
# Processing Record 17 of Set 3 | bucyrus
# Processing Record 18 of Set 3 | arraial do cabo
# Processing Record 19 of Set 3 | salta
# Processing Record 20 of Set 3 | grand gaube
# Processing Record 21 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 3 | avera
# Processing Record 23 of Set 3 | lorengau
# Processing Record 24 of Set 3 | punta arenas
# Processing Record 25 of Set 3 | bethel
# Processing Record 26 of Set 3 | port-gentil
# Processing Record 27 of Set 3 | srednekolymsk
# Processing Record 28 of Set 3 | bluff
# Processing Record 29 of Set 3 | lesnikovo
# Processing Record 30 of Set 3 | coihaique
# Processing Record 31 of Set 3 | gladstone
# Processing Record 32 of Set 3 | sinnamary
# Processing Record 33 of Set 3 | chokurdakh
# Processing Record 34 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 3 | saint george
# Processing Record 37 of Set 3 | north las vegas
# Processing Record 38 of Set 3 | pitimbu
# Processing Record 39 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 3 | kirakira
# Processing Record 41 of Set 3 | marsh harbour
# Processing Record 42 of Set 3 | kodiak
# Processing Record 43 of Set 3 | dali
# Processing Record 44 of Set 3 | damghan
# Processing Record 45 of Set 3 | lawar
# City not found. Skipping...
# Processing Record 46 of Set 3 | khatanga
# Processing Record 47 of Set 3 | damietta
# Processing Record 48 of Set 3 | arvika
# Processing Record 49 of Set 3 | ponta do sol
# Processing Record 50 of Set 3 | esfarayen
# Processing Record 1 of Set 4 | ugoofaaru
# Processing Record 2 of Set 4 | inirida
# Processing Record 3 of Set 4 | mucuri
# Processing Record 4 of Set 4 | constitucion
# Processing Record 5 of Set 4 | gayny
# Processing Record 6 of Set 4 | sabang
# Processing Record 7 of Set 4 | ialibu
# Processing Record 8 of Set 4 | manono
# Processing Record 9 of Set 4 | smithers
# Processing Record 10 of Set 4 | vanimo
# Processing Record 11 of Set 4 | saint-georges
# Processing Record 12 of Set 4 | haifa
# Processing Record 13 of Set 4 | zyryanovsk
# Processing Record 14 of Set 4 | guerrero negro
# Processing Record 15 of Set 4 | morant bay
# Processing Record 16 of Set 4 | norman wells
# Processing Record 17 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 4 | faya
# Processing Record 19 of Set 4 | ciudad ojeda
# Processing Record 20 of Set 4 | quelimane
# Processing Record 21 of Set 4 | mabaruma
# Processing Record 22 of Set 4 | college
# Processing Record 23 of Set 4 | hilo
# Processing Record 24 of Set 4 | thompson
# Processing Record 25 of Set 4 | suclayin
# Processing Record 26 of Set 4 | zhangye
# Processing Record 27 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 4 | severo-kurilsk
# Processing Record 30 of Set 4 | bogande
# Processing Record 31 of Set 4 | dom pedrito
# Processing Record 32 of Set 4 | isla mujeres
# Processing Record 33 of Set 4 | hami
# Processing Record 34 of Set 4 | fortuna
# Processing Record 35 of Set 4 | berlevag
# Processing Record 36 of Set 4 | pahrump
# Processing Record 37 of Set 4 | innisfail
# Processing Record 38 of Set 4 | waingapu
# Processing Record 39 of Set 4 | codrington
# Processing Record 40 of Set 4 | polonnaruwa
# Processing Record 41 of Set 4 | chapais
# Processing Record 42 of Set 4 | niort
# Processing Record 43 of Set 4 | maramba
# Processing Record 44 of Set 4 | maniitsoq
# Processing Record 45 of Set 4 | severnoye
# Processing Record 46 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 4 | sept-iles
# Processing Record 48 of Set 4 | severomuysk
# Processing Record 49 of Set 4 | konstantinovskiy
# Processing Record 50 of Set 4 | korla
# Processing Record 1 of Set 5 | aykhal
# Processing Record 2 of Set 5 | mvuma
# Processing Record 3 of Set 5 | cockburn town
# Processing Record 4 of Set 5 | tainan
# Processing Record 5 of Set 5 | hamilton
# Processing Record 6 of Set 5 | lugo
# Processing Record 7 of Set 5 | marystown
# Processing Record 8 of Set 5 | new norfolk
# Processing Record 9 of Set 5 | porterville
# Processing Record 10 of Set 5 | yatou
# Processing Record 11 of Set 5 | port alfred
# Processing Record 12 of Set 5 | shingu
# Processing Record 13 of Set 5 | geraldton
# Processing Record 14 of Set 5 | tynda
# Processing Record 15 of Set 5 | iqaluit
# Processing Record 16 of Set 5 | kununurra
# Processing Record 17 of Set 5 | cabo san lucas
# Processing Record 18 of Set 5 | beloha
# Processing Record 19 of Set 5 | inuvik
# Processing Record 20 of Set 5 | mukhen
# Processing Record 21 of Set 5 | nelson
# Processing Record 22 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 23 of Set 5 | fairbanks
# Processing Record 24 of Set 5 | urumqi
# Processing Record 25 of Set 5 | yaransk
# Processing Record 26 of Set 5 | pemangkat
# Processing Record 27 of Set 5 | bathsheba
# Processing Record 28 of Set 5 | coxim
# Processing Record 29 of Set 5 | san policarpo
# Processing Record 30 of Set 5 | bambous virieux
# Processing Record 31 of Set 5 | sao filipe
# Processing Record 32 of Set 5 | namatanai
# Processing Record 33 of Set 5 | raga
# Processing Record 34 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 35 of Set 5 | urulga
# City not found. Skipping...
# Processing Record 36 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 5 | xingyi
# Processing Record 38 of Set 5 | touros
# Processing Record 39 of Set 5 | faanui
# Processing Record 40 of Set 5 | mount isa
# Processing Record 41 of Set 5 | maldonado
# Processing Record 42 of Set 5 | jieshi
# Processing Record 43 of Set 5 | marks
# Processing Record 44 of Set 5 | yerbogachen
# Processing Record 45 of Set 5 | bukene
# Processing Record 46 of Set 5 | lerwick
# Processing Record 47 of Set 5 | george
# Processing Record 48 of Set 5 | sturgis
# Processing Record 49 of Set 5 | aksu
# Processing Record 50 of Set 5 | souillac
# Processing Record 1 of Set 6 | haines junction
# Processing Record 2 of Set 6 | praia
# Processing Record 3 of Set 6 | naryan-mar
# Processing Record 4 of Set 6 | mackay
# Processing Record 5 of Set 6 | wagar
# Processing Record 6 of Set 6 | husavik
# Processing Record 7 of Set 6 | puerto ayora
# Processing Record 8 of Set 6 | meulaboh
# Processing Record 9 of Set 6 | northam
# Processing Record 10 of Set 6 | muisne
# Processing Record 11 of Set 6 | lysva
# Processing Record 12 of Set 6 | nenjiang
# Processing Record 13 of Set 6 | ust-ilimsk
# Processing Record 14 of Set 6 | richards bay
# Processing Record 15 of Set 6 | caravelas
# Processing Record 16 of Set 6 | salalah
# Processing Record 17 of Set 6 | klaksvik
# Processing Record 18 of Set 6 | svetlyy
# Processing Record 19 of Set 6 | merauke
# Processing Record 20 of Set 6 | remontnoye
# Processing Record 21 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 6 | linguere
# Processing Record 23 of Set 6 | methoni
# Processing Record 24 of Set 6 | sharjah
# Processing Record 25 of Set 6 | olga
# Processing Record 26 of Set 6 | aksarka
# Processing Record 27 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 6 | tokmak
# Processing Record 29 of Set 6 | albion
# Processing Record 30 of Set 6 | beitbridge
# Processing Record 31 of Set 6 | dingle
# Processing Record 32 of Set 6 | kenai
# Processing Record 33 of Set 6 | nome
# Processing Record 34 of Set 6 | ballina
# Processing Record 35 of Set 6 | shiyan
# Processing Record 36 of Set 6 | margosatubig
# Processing Record 37 of Set 6 | arroyo
# Processing Record 38 of Set 6 | shimoda
# Processing Record 39 of Set 6 | otjiwarongo
# Processing Record 40 of Set 6 | kavaratti
# Processing Record 41 of Set 6 | qaqortoq
# Processing Record 42 of Set 6 | vidim
# Processing Record 43 of Set 6 | kloulklubed
# Processing Record 44 of Set 6 | beringovskiy
# Processing Record 45 of Set 6 | pilar
# Processing Record 46 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 6 | znamenskoye
# Processing Record 48 of Set 6 | moses lake
# Processing Record 49 of Set 6 | ivangorod
# Processing Record 50 of Set 6 | baghdad
# Processing Record 1 of Set 7 | gannan
# Processing Record 2 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 3 of Set 7 | paita
# Processing Record 4 of Set 7 | sistranda
# Processing Record 5 of Set 7 | floro
# Processing Record 6 of Set 7 | anadyr
# Processing Record 7 of Set 7 | maralal
# Processing Record 8 of Set 7 | nyurba
# Processing Record 9 of Set 7 | seoul
# Processing Record 10 of Set 7 | port hedland
# Processing Record 11 of Set 7 | troitsko-pechorsk
# Processing Record 12 of Set 7 | nsanje
# Processing Record 13 of Set 7 | bani walid
# Processing Record 14 of Set 7 | ukiah
# Processing Record 15 of Set 7 | senador guiomard
# Processing Record 16 of Set 7 | hibbing
# Processing Record 17 of Set 7 | palmer
# Processing Record 18 of Set 7 | jacareacanga
# Processing Record 19 of Set 7 | port lincoln
# Processing Record 20 of Set 7 | ust-nera
# Processing Record 21 of Set 7 | deyang
# Processing Record 22 of Set 7 | lagos
# Processing Record 23 of Set 7 | viedma
# Processing Record 24 of Set 7 | marawi
# Processing Record 25 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 26 of Set 7 | christchurch
# Processing Record 27 of Set 7 | kabalo
# Processing Record 28 of Set 7 | prestea
# Processing Record 29 of Set 7 | portland
# Processing Record 30 of Set 7 | margate
# Processing Record 31 of Set 7 | alofi
# Processing Record 32 of Set 7 | nantucket
# Processing Record 33 of Set 7 | port blair
# Processing Record 34 of Set 7 | celestun
# Processing Record 35 of Set 7 | sovetskiy
# Processing Record 36 of Set 7 | almaznyy
# Processing Record 37 of Set 7 | broken hill
# Processing Record 38 of Set 7 | sioux city
# Processing Record 39 of Set 7 | lavrentiya
# Processing Record 40 of Set 7 | kotma
# Processing Record 41 of Set 7 | malkerns
# Processing Record 42 of Set 7 | haimen
# Processing Record 43 of Set 7 | pizarro
# Processing Record 44 of Set 7 | pinotepa nacional
# Processing Record 45 of Set 7 | saint-joseph
# Processing Record 46 of Set 7 | dombarovskiy
# Processing Record 47 of Set 7 | tahe
# Processing Record 48 of Set 7 | nelson bay
# Processing Record 49 of Set 7 | vila velha
# Processing Record 50 of Set 7 | kerema
# Processing Record 1 of Set 8 | hobyo
# Processing Record 2 of Set 8 | puerto rico
# Processing Record 3 of Set 8 | niesky
# Processing Record 4 of Set 8 | rawson
# Processing Record 5 of Set 8 | vila franca do campo
# Processing Record 6 of Set 8 | dunedin
# Processing Record 7 of Set 8 | kruisfontein
# Processing Record 8 of Set 8 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 9 of Set 8 | ippy
# Processing Record 10 of Set 8 | itarema
# Processing Record 11 of Set 8 | hasaki
# Processing Record 12 of Set 8 | sfantu gheorghe
# Processing Record 13 of Set 8 | maceio
# Processing Record 14 of Set 8 | bairiki
# Processing Record 15 of Set 8 | nouadhibou
# Processing Record 16 of Set 8 | tambura
# Processing Record 17 of Set 8 | maku
# Processing Record 18 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 19 of Set 8 | mazyr
# Processing Record 20 of Set 8 | voh
# Processing Record 21 of Set 8 | durban
# Processing Record 22 of Set 8 | zaraza
# Processing Record 23 of Set 8 | caraballeda
# Processing Record 24 of Set 8 | alexandria
# Processing Record 25 of Set 8 | hambantota
# Processing Record 26 of Set 8 | duvan
# Processing Record 27 of Set 8 | santa rosa
# Processing Record 28 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 29 of Set 8 | coahuayana
# Processing Record 30 of Set 8 | camopi
# Processing Record 31 of Set 8 | aklavik
# Processing Record 32 of Set 8 | saint-felicien
# Processing Record 33 of Set 8 | ribeira brava
# Processing Record 34 of Set 8 | abu dhabi
# Processing Record 35 of Set 8 | longyearbyen
# Processing Record 36 of Set 8 | le port
# Processing Record 37 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 38 of Set 8 | kinsale
# Processing Record 39 of Set 8 | pital
# Processing Record 40 of Set 8 | nevelsk
# Processing Record 41 of Set 8 | saint-pierre
# Processing Record 42 of Set 8 | sant feliu de guixols
# Processing Record 43 of Set 8 | yershov
# Processing Record 44 of Set 8 | prieska
# Processing Record 45 of Set 8 | sahrak
# City not found. Skipping...
# Processing Record 46 of Set 8 | dutse
# Processing Record 47 of Set 8 | najran
# Processing Record 48 of Set 8 | byron bay
# Processing Record 49 of Set 8 | tiarei
# Processing Record 50 of Set 8 | yulara
# Processing Record 1 of Set 9 | villa bruzual
# Processing Record 2 of Set 9 | la ronge
# Processing Record 3 of Set 9 | tommot
# Processing Record 4 of Set 9 | lephepe
# City not found. Skipping...
# Processing Record 5 of Set 9 | lompoc
# Processing Record 6 of Set 9 | tieling
# Processing Record 7 of Set 9 | yuryevets
# Processing Record 8 of Set 9 | chuy
# Processing Record 9 of Set 9 | quebrada de yoro
# City not found. Skipping...
# Processing Record 10 of Set 9 | muravlenko
# Processing Record 11 of Set 9 | ifanadiana
# Processing Record 12 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 13 of Set 9 | sur
# Processing Record 14 of Set 9 | praia da vitoria
# Processing Record 15 of Set 9 | kachiry
# Processing Record 16 of Set 9 | pacific grove
# Processing Record 17 of Set 9 | san patricio
# Processing Record 18 of Set 9 | tual
# Processing Record 19 of Set 9 | rocha
# Processing Record 20 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 9 | kroya
# Processing Record 22 of Set 9 | akyab
# Processing Record 23 of Set 9 | quatre cocos
# Processing Record 24 of Set 9 | bukachacha
# Processing Record 25 of Set 9 | antequera
# Processing Record 26 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 27 of Set 9 | zabaykalsk
# Processing Record 28 of Set 9 | soria
# Processing Record 29 of Set 9 | taltal
# Processing Record 30 of Set 9 | magadan
# Processing Record 31 of Set 9 | babina
# Processing Record 32 of Set 9 | deputatskiy
# Processing Record 33 of Set 9 | seymchan
# Processing Record 34 of Set 9 | kharp
# Processing Record 35 of Set 9 | sioux lookout
# Processing Record 36 of Set 9 | shwebo
# Processing Record 37 of Set 9 | atar
# Processing Record 38 of Set 9 | port macquarie
# Processing Record 39 of Set 9 | vardo
# Processing Record 40 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 41 of Set 9 | volchikha
# Processing Record 42 of Set 9 | hodmezovasarhely
# Processing Record 43 of Set 9 | okha
# Processing Record 44 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 45 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 46 of Set 9 | milkovo
# Processing Record 47 of Set 9 | kondinskoye
# Processing Record 48 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 49 of Set 9 | lamu
# Processing Record 50 of Set 9 | inhambane
# Processing Record 1 of Set 10 | calamar
# Processing Record 2 of Set 10 | kumluca
# Processing Record 3 of Set 10 | tabarqah
# City not found. Skipping...
# Processing Record 4 of Set 10 | abrau-dyurso
# Processing Record 5 of Set 10 | oktyabrskiy
# Processing Record 6 of Set 10 | nikolayevskaya
# Processing Record 7 of Set 10 | pombas
# Processing Record 8 of Set 10 | masindi
# Processing Record 9 of Set 10 | surt
# Processing Record 10 of Set 10 | shagonar
# Processing Record 11 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 10 | abu samrah
# Processing Record 13 of Set 10 | saint-augustin
# Processing Record 14 of Set 10 | gavle
# Processing Record 15 of Set 10 | san cristobal
# Processing Record 16 of Set 10 | khandyga
# Processing Record 17 of Set 10 | bam
# Processing Record 18 of Set 10 | la rioja
# Processing Record 19 of Set 10 | taoudenni
# Processing Record 20 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 10 | paamiut
# Processing Record 22 of Set 10 | prachuap khiri khan
# Processing Record 23 of Set 10 | uvira
# Processing Record 24 of Set 10 | emirdag
# Processing Record 25 of Set 10 | belaya gora
# Processing Record 26 of Set 10 | praxedis guerrero
# Processing Record 27 of Set 10 | chililabombwe
# Processing Record 28 of Set 10 | kasongo-lunda
# Processing Record 29 of Set 10 | ayagoz
# Processing Record 30 of Set 10 | fort-shevchenko
# Processing Record 31 of Set 10 | impfondo
# Processing Record 32 of Set 10 | oyon
# Processing Record 33 of Set 10 | chibuto
# Processing Record 34 of Set 10 | general pico
# Processing Record 35 of Set 10 | morro bay
# Processing Record 36 of Set 10 | ojinaga
# Processing Record 37 of Set 10 | ahipara
# Processing Record 38 of Set 10 | nova odesa
# Processing Record 39 of Set 10 | alta
# Processing Record 40 of Set 10 | port augusta
# Processing Record 41 of Set 10 | juneau
# Processing Record 42 of Set 10 | ipil
# Processing Record 43 of Set 10 | hirara
# Processing Record 44 of Set 10 | alice springs
# Processing Record 45 of Set 10 | trincomalee
# Processing Record 46 of Set 10 | mopipi
# Processing Record 47 of Set 10 | adre
# Processing Record 48 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 49 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 10 | aksay
# Processing Record 1 of Set 11 | winslow
# Processing Record 2 of Set 11 | san carlos
# Processing Record 3 of Set 11 | novoagansk
# Processing Record 4 of Set 11 | kapit
# Processing Record 5 of Set 11 | windsor
# Processing Record 6 of Set 11 | kisesa
# Processing Record 7 of Set 11 | port pirie
# Processing Record 8 of Set 11 | chivilcoy
# Processing Record 9 of Set 11 | monte alegre
# Processing Record 10 of Set 11 | lincoln
# Processing Record 11 of Set 11 | yar-sale
# Processing Record 12 of Set 11 | coari
# Processing Record 13 of Set 11 | morondava
# Processing Record 14 of Set 11 | olafsvik
# Processing Record 15 of Set 11 | sabha
# Processing Record 16 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 11 | barysh
# Processing Record 18 of Set 11 | lasa
# Processing Record 19 of Set 11 | nisia floresta
# Processing Record 20 of Set 11 | maurawan
# Processing Record 21 of Set 11 | port keats
# Processing Record 22 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 23 of Set 11 | doune
# Processing Record 24 of Set 11 | wajid
# Processing Record 25 of Set 11 | seydi
# Processing Record 26 of Set 11 | luanda
# Processing Record 27 of Set 11 | sawakin
# Processing Record 28 of Set 11 | cheremukhovo
# Processing Record 29 of Set 11 | baoma
# Processing Record 30 of Set 11 | nueva loja
# Processing Record 31 of Set 11 | asau
# Processing Record 32 of Set 11 | havelock
# Processing Record 33 of Set 11 | pailon
# Processing Record 34 of Set 11 | charleston
# Processing Record 35 of Set 11 | mount gambier
# Processing Record 36 of Set 11 | antalaha
# Processing Record 37 of Set 11 | ndele
# Processing Record 38 of Set 11 | solnechnyy
# Processing Record 39 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 11 | samarai
# Processing Record 41 of Set 11 | chumikan
# Processing Record 42 of Set 11 | sterling
# Processing Record 43 of Set 11 | laurel
# Processing Record 44 of Set 11 | mormugao
# Processing Record 45 of Set 11 | lesosibirsk
# Processing Record 46 of Set 11 | pandan
# Processing Record 47 of Set 11 | angicos
# Processing Record 48 of Set 11 | general roca
# Processing Record 49 of Set 11 | guanare
# Processing Record 50 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 12 | santa luzia
# Processing Record 2 of Set 12 | saint pete beach
# Processing Record 3 of Set 12 | donskoye
# Processing Record 4 of Set 12 | rwamagana
# Processing Record 5 of Set 12 | leningradskiy
# Processing Record 6 of Set 12 | sao joao da barra
# Processing Record 7 of Set 12 | ancud
# Processing Record 8 of Set 12 | searcy
# Processing Record 9 of Set 12 | pisco
# Processing Record 10 of Set 12 | lagoa
# Processing Record 11 of Set 12 | hervey bay
# Processing Record 12 of Set 12 | udachnyy
# Processing Record 13 of Set 12 | wattegama
# Processing Record 14 of Set 12 | faridpur
# Processing Record 15 of Set 12 | sitka
# Processing Record 16 of Set 12 | bodaybo
# Processing Record 17 of Set 12 | vostok
# Processing Record 18 of Set 12 | penzance
# Processing Record 19 of Set 12 | peniche
# Processing Record 20 of Set 12 | jupiter
# Processing Record 21 of Set 12 | te anau
# Processing Record 22 of Set 12 | amapa
# Processing Record 23 of Set 12 | mpraeso
# Processing Record 24 of Set 12 | burnie
# Processing Record 25 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 26 of Set 12 | douglas
# Processing Record 27 of Set 12 | orodara
# Processing Record 28 of Set 12 | den helder
# Processing Record 29 of Set 12 | camacha
# Processing Record 30 of Set 12 | howard springs
# Processing Record 31 of Set 12 | emba
# Processing Record 32 of Set 12 | yumen
# Processing Record 33 of Set 12 | livingston
# Processing Record 34 of Set 12 | balsas
# Processing Record 35 of Set 12 | rocky mountain house
# Processing Record 36 of Set 12 | homer
# Processing Record 37 of Set 12 | camiri
# Processing Record 38 of Set 12 | padang
# Processing Record 39 of Set 12 | laguna
# Processing Record 40 of Set 12 | kjollefjord
# Processing Record 41 of Set 12 | chiang rai
# Processing Record 42 of Set 12 | pocone
# Processing Record 43 of Set 12 | kutum
# Processing Record 44 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 12 | comodoro rivadavia
# Processing Record 46 of Set 12 | auki
# Processing Record 47 of Set 12 | canatlan
# Processing Record 48 of Set 12 | vanino
# Processing Record 49 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 50 of Set 12 | sola
# Processing Record 1 of Set 13 | hofn
# Processing Record 2 of Set 13 | the valley
# Processing Record 3 of Set 13 | channel-port aux basques
# Processing Record 4 of Set 13 | kingaroy
# Processing Record 5 of Set 13 | mayo
# Processing Record 6 of Set 13 | victor harbor
# Processing Record 7 of Set 13 | wilmington island
# Processing Record 8 of Set 13 | kampot
# Processing Record 9 of Set 13 | kailua
# Processing Record 10 of Set 13 | ascension
# Processing Record 11 of Set 13 | bahia blanca
# Processing Record 12 of Set 13 | north port
# Processing Record 13 of Set 13 | port hawkesbury
# Processing Record 14 of Set 13 | bambanglipuro
# Processing Record 15 of Set 13 | turukhansk
# Processing Record 16 of Set 13 | broome
# Processing Record 17 of Set 13 | cooma
# Processing Record 18 of Set 13 | sault sainte marie
# Processing Record 19 of Set 13 | ostrovnoy
# Processing Record 20 of Set 13 | calnali
# Processing Record 21 of Set 13 | maragogi
# Processing Record 22 of Set 13 | brufut
# Processing Record 23 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 13 | urengoy
# Processing Record 25 of Set 13 | katsuura
# Processing Record 26 of Set 13 | okato
# Processing Record 27 of Set 13 | saint-francois
# Processing Record 28 of Set 13 | sitamau
# Processing Record 29 of Set 13 | afua
# Processing Record 30 of Set 13 | brewster
# Processing Record 31 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 32 of Set 13 | tromso
# Processing Record 33 of Set 13 | bajo baudo
# City not found. Skipping...
# Processing Record 34 of Set 13 | moultrie
# Processing Record 35 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 36 of Set 13 | nachalovo
# Processing Record 37 of Set 13 | shakiso
# Processing Record 38 of Set 13 | kaseda
# Processing Record 39 of Set 13 | chicama
# Processing Record 40 of Set 13 | boden
# Processing Record 41 of Set 13 | biak
# Processing Record 42 of Set 13 | pangkalanbuun
# Processing Record 43 of Set 13 | ewa beach
# Processing Record 44 of Set 13 | budogoshch
# Processing Record 45 of Set 13 | bandarbeyla
# Processing Record 46 of Set 13 | lapeer
# Processing Record 47 of Set 13 | altamont
# Processing Record 48 of Set 13 | marilandia
# Processing Record 49 of Set 13 | arica
# Processing Record 50 of Set 13 | tukrah
# Processing Record 1 of Set 14 | prosyana
# City not found. Skipping...
# Processing Record 2 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 3 of Set 14 | gurupa
# Processing Record 4 of Set 14 | alegrete
# Processing Record 5 of Set 14 | patterson
# Processing Record 6 of Set 14 | rondonopolis
# Processing Record 7 of Set 14 | mpongwe
# Processing Record 8 of Set 14 | caraquet
# Processing Record 9 of Set 14 | maxixe
# Processing Record 10 of Set 14 | pancol
# Processing Record 11 of Set 14 | kahta
# Processing Record 12 of Set 14 | ajdabiya
# Processing Record 13 of Set 14 | tulsipur
# Processing Record 14 of Set 14 | alekseyevka
# Processing Record 15 of Set 14 | nara
# Processing Record 16 of Set 14 | tambacounda
# Processing Record 17 of Set 14 | roald
# Processing Record 18 of Set 14 | biggar
# Processing Record 19 of Set 14 | goderich
# Processing Record 20 of Set 14 | zemio
# Processing Record 21 of Set 14 | vanersborg
# Processing Record 22 of Set 14 | harta
# Processing Record 23 of Set 14 | twentynine palms
# Processing Record 24 of Set 14 | druzhba
# Processing Record 25 of Set 14 | wajir
# Processing Record 26 of Set 14 | sawtell
# Processing Record 27 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 28 of Set 14 | kaduy
# Processing Record 29 of Set 14 | chunskiy
# Processing Record 30 of Set 14 | ngorongoro
# Processing Record 31 of Set 14 | youkounkoun
# Processing Record 32 of Set 14 | itoman
# Processing Record 33 of Set 14 | vilhena
# Processing Record 34 of Set 14 | purbalingga
# Processing Record 35 of Set 14 | liling
# Processing Record 36 of Set 14 | buala
# Processing Record 37 of Set 14 | taihe
# Processing Record 38 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 39 of Set 14 | tevriz
# Processing Record 40 of Set 14 | marysville
# Processing Record 41 of Set 14 | itaqui
# Processing Record 42 of Set 14 | leh
# Processing Record 43 of Set 14 | semnan
# Processing Record 44 of Set 14 | pueblo
# Processing Record 45 of Set 14 | rafai
# Processing Record 46 of Set 14 | kawalu
# Processing Record 47 of Set 14 | muriwai beach
# Processing Record 48 of Set 14 | sayyan
# Processing Record 49 of Set 14 | challans
# Processing Record 50 of Set 14 | nishihara
# Processing Record 1 of Set 15 | davidson
# Processing Record 2 of Set 15 | havoysund
# Processing Record 3 of Set 15 | lima
# Processing Record 4 of Set 15 | norden
# Processing Record 5 of Set 15 | plattling
# Processing Record 6 of Set 15 | oyama
# Processing Record 7 of Set 15 | klaebu
# Processing Record 8 of Set 15 | ak-dovurak
# Processing Record 9 of Set 15 | del rio
# Processing Record 10 of Set 15 | penarroya-pueblonuevo
# Processing Record 11 of Set 15 | xiaoweizhai
# Processing Record 12 of Set 15 | teeli
# Processing Record 13 of Set 15 | north bend
# Processing Record 14 of Set 15 | thibodaux
# Processing Record 15 of Set 15 | takoradi
# Processing Record 16 of Set 15 | nador
# Processing Record 17 of Set 15 | utete
# Processing Record 18 of Set 15 | los llanos de aridane
# Processing Record 19 of Set 15 | marand
# Processing Record 20 of Set 15 | jiaocheng
# Processing Record 21 of Set 15 | naze
# Processing Record 22 of Set 15 | barinas
# Processing Record 23 of Set 15 | sar-e pul
# Processing Record 24 of Set 15 | gorodishche
# Processing Record 25 of Set 15 | chimore
# Processing Record 26 of Set 15 | manggar
# Processing Record 27 of Set 15 | gharghoda
# Processing Record 28 of Set 15 | wajima
# Processing Record 29 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 15 | parabel
# Processing Record 31 of Set 15 | miranorte
# City not found. Skipping...
# Processing Record 32 of Set 15 | amahai
# Processing Record 33 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 34 of Set 15 | amol
# Processing Record 35 of Set 15 | preobrazheniye
# Processing Record 36 of Set 15 | dunmore east
# Processing Record 37 of Set 15 | la sarre
# Processing Record 38 of Set 15 | valparaiso
# Processing Record 39 of Set 15 | bowen
# Processing Record 40 of Set 15 | koungou
# Processing Record 41 of Set 15 | garissa
# Processing Record 42 of Set 15 | saint combs
# City not found. Skipping...
# Processing Record 43 of Set 15 | kiruna
# Processing Record 44 of Set 15 | namibe
# Processing Record 45 of Set 15 | vagur
# Processing Record 46 of Set 15 | saldanha
# Processing Record 47 of Set 15 | bonthe
# Processing Record 48 of Set 15 | tiznit
# Processing Record 49 of Set 15 | trinidad
# Processing Record 50 of Set 15 | puksoozero
# Processing Record 1 of Set 16 | lerik
# Processing Record 2 of Set 16 | ambon
# Processing Record 3 of Set 16 | normandin
# Processing Record 4 of Set 16 | yeletskiy
# City not found. Skipping...
# Processing Record 5 of Set 16 | robertsport
# Processing Record 6 of Set 16 | pereira barreto
# Processing Record 7 of Set 16 | verdalsora
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 689

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Bredasdorp      ZA -34.5322   20.0403     57.61        73          78
# 1      Port Hardy      CA  50.6996 -127.4199     48.38        87          75
# 2        Coquimbo      CL -29.9533  -71.3436     58.73        88          75
# 3          Riyadh      SA  24.6877   46.7219     75.34        45          95
# 4           Vaini      TO -21.2000 -175.2000     82.56        74          75
# 5          Hailar      CN  49.2000  119.7000     38.28        41         100
# 6          Aitape      PG  -3.1374  142.3475     80.28        85          88
# 7          Hobart      AU -42.8794  147.3294     55.26        90          75
# 8  Saint-Philippe      RE -21.3585   55.7679     74.79        79          90
# 9         Rikitea      PF -23.1203 -134.9692     73.02        89         100
#
#    Wind Speed Current Description
# 0        5.55          light rain
# 1       18.41          light rain
# 2        6.91       broken clouds
# 3       13.27     overcast clouds
# 4        4.61       broken clouds
# 5        9.35     overcast clouds
# 6        3.94     overcast clouds
# 7        1.01       broken clouds
# 8       14.03          light rain
# 9       16.44       moderate rain

# %%
output_data_file = "WeatherPy_Database.csv"
#Export the city_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
